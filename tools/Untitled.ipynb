# %%
# %matplotlib inline

# %%
plt.show()

# %%
run cogging_smoother.py
# Out:
# finding an odrive...
# running manual...
# Bus voltage is 12.212255477905273V
# Grabbing data..
# Plotting..
# You pressed Ctrl+C!
# Exiting..

# %%
d

# %%
d.data.shape
# Out:
# (1204,)

# %%
wrap = np.argmax(np.fabs(d.data[:-1] - d.data[1:]))
d.data[wrap + 1:] -= 2 * np.pi

expected = np.linspace(d.data[0], d.data[-1], d.data.size)
d.data -= expected

# %%
plt.plot(d.data)

# %%
run cogging_smoother.py
# Out:
# finding an odrive...
# running manual...
# Bus voltage is 12.20339298248291V
# Grabbing data..
# Plotting..
# You pressed Ctrl+C!
# Exiting..

# %%
run cogging_smoother.py
# Out:
# finding an odrive...
# running manual...
# Bus voltage is 12.24770450592041V
# Grabbing data..
# Plotting..
# You pressed Ctrl+C!
# Exiting..

# %%
run cogging_smoother.py
# Out:
# finding an odrive...
# running manual...
# Bus voltage is 12.283154487609863V
# Grabbing data..
# Plotting..
# Uploading data..
# Data uploaded
# 5.0
# 10.0
# 15.0
# 20.0
# -5.0
# -10.0
# -15.0
# -20.0
# depths tried
# You pressed Ctrl+C!
# Exiting..

# %%
odrv0.axis0.mod_depth=-10
